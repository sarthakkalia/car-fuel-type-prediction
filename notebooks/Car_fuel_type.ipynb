# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv('quikr_car.csv')
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.shape
# Out:
# (892, 6)

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
df['kms_driven']=df['kms_driven'].str.split('kms').str[0]

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#   kms_driven fuel_type
# 0    45,000     Petrol
# 1        40     Diesel
# 2    22,000     Petrol
# 3    28,000     Petrol
# 4    36,000     Diesel

# %%
df['kms_driven']=df['kms_driven'].str.split(' ').str[0]

# %%
df['kms_driven']=df['kms_driven'].str.replace(',','')

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#   kms_driven fuel_type
# 0      45000    Petrol
# 1         40    Diesel
# 2      22000    Petrol
# 3      28000    Petrol
# 4      36000    Diesel

# %%
# df[~df['kms_driven'].isnull()]

# %%
df['kms_driven'] = df['kms_driven'].astype(str)

# %%
df['kms_driven'].shape
# Out:
# (892,)

# %%
df[~df['kms_driven'].str.isdigit()]
# Out:
#                                        name     company  year          Price  \
# 69          I want to sell my car Tata Zest           I  2017  Ask For Price
# 85          I want to sell my car Tata Zest           I  2017  Ask For Price
# 185  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 195                 Tata indigo ecs LX, 201        Tata  150k       1,50,000
# 206                      MARUTI SUZUKI DESI      MARUTI  TOUR       4,00,000
# 286  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 294                                    Yama      Yamaha  r 15         55,000
# 360                          selling car Ta     selling  Zest  Ask For Price
# 368                            Tata Zest 90        Tata  /-Rs  Ask For Price
# 385           Maruti Suzuki Swift Dzire car      Maruti  sale       3,00,000
# 395     Maruti Suzuki Swift Dzire Tour (Gat      Maruti  ara)       3,00,000
# ...

# %%
df['kms_driven'] = pd.to_numeric(df['kms_driven'], errors='coerce')

# %%
df.shape
# Out:
# (892, 6)

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0     45000.0    Petrol
# 1        40.0    Diesel
# 2     22000.0    Petrol
# 3     28000.0    Petrol
# 4     36000.0    Diesel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  838 non-null    float64
#  5   fuel_type   837 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 41.9+ KB

# %%
df['kms_driven'].mean()
# Out:
# 46010.55011933174

# %%
df['kms_driven'].median()
# Out:
# 41000.0

# %%
df['kms_driven'].isnull().sum()
# Out:
# 54

# %%
sns.histplot(data=df,x=df['kms_driven'],bins=30,kde=True)
# Out:
# <Axes: xlabel='kms_driven', ylabel='Count'>

# %%
df['kms_driven'].fillna(df['kms_driven'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven     0
# fuel_type     55
# dtype: int64

# %%
df['fuel_type']=df['fuel_type'].str.strip()

# %%
df['fuel_type'].isnull().sum()
# Out:
# 55

# %%
df['fuel_type'].mode()
# Out:
# 0    Petrol
# Name: fuel_type, dtype: object

# %%
df['fuel_type'].fillna(df['fuel_type'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  892 non-null    float64
#  5   fuel_type   892 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 41.9+ KB

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0     45000.0    Petrol
# 1        40.0    Diesel
# 2     22000.0    Petrol
# 3     28000.0    Petrol
# 4     36000.0    Diesel

# %%
df[~df['year'].str.isnumeric()]
# Out:
#                                        name     company  year          Price  \
# 185  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 195                 Tata indigo ecs LX, 201        Tata  150k       1,50,000
# 206                      MARUTI SUZUKI DESI      MARUTI  TOUR       4,00,000
# 286  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 294                                    Yama      Yamaha  r 15         55,000
# 360                          selling car Ta     selling  Zest  Ask For Price
# 368                            Tata Zest 90        Tata  /-Rs  Ask For Price
# 385           Maruti Suzuki Swift Dzire car      Maruti  sale       3,00,000
# 395     Maruti Suzuki Swift Dzire Tour (Gat      Maruti  ara)       3,00,000
# 401                                    URJE      URJENT  SELL       1,80,000
# 414      Swift Dzire Tour 27 Dec 2016 Regis       Swift  tion       3,70,000
# ...

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %%
df['year'].median()
# Out:
# 2013.0

# %%
df[~df['year'].isnull()]
# Out:
#                                        name    company    year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007.0         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006.0       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018.0  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014.0       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014.0       5,75,000
# ..                                      ...        ...     ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009.0       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018.0       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013.0       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014.0       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014.0       1,60,000
#
#      kms_driven fuel_type
# ...

# %%
df['year'].fillna(df['year'].median(),inplace=True)

# %%
df['year']=df['year'].astype(int)

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0     45000.0    Petrol
# 1        40.0    Diesel
# 2     22000.0    Petrol
# 3     28000.0    Petrol
# 4     36000.0    Diesel

# %%
df['Price']=df['Price'].str.replace(',','')

# %%
df[~df['Price'].str.isnumeric()]
# Out:
#                                           name     company  year  \
# 2                   Maruti Suzuki Alto 800 Vxi      Maruti  2018
# 5             Ford EcoSport Titanium 1.5L TDCi        Ford  2015
# 69             I want to sell my car Tata Zest           I  2017
# 85             I want to sell my car Tata Zest           I  2017
# 138                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 185     Commercial , DZire LDI, 2016, for sale  Commercial  2013
# 286     Commercial , DZire LDI, 2016, for sale  Commercial  2013
# 295                    Maruti Suzuki Swift LDi      Maruti  2010
# 304                         Tata Indica eV2 LS        Tata  2017
# 360                             selling car Ta     selling  2013
# 368                               Tata Zest 90        Tata  2013
# 388                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 449     Maruti Suzuki Zen Estilo LXI Green CNG      Maruti  2011
# ...

# %%
df['Price']=df['Price'].str.replace('Ask For Price','0')

# %%
df['Price']=df['Price'].astype(float)

# %%
df.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.0
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018       0.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.0
#
#    kms_driven fuel_type
# 0     45000.0    Petrol
# 1        40.0    Diesel
# 2     22000.0    Petrol
# 3     28000.0    Petrol
# 4     36000.0    Diesel

# %%
df['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Commercial', 'MARUTI', 'Force', 'Mercedes', 'Land', 'Yamaha',
#        'selling', 'URJENT', 'Swift', 'Used', 'Jaguar', 'Jeep', 'tata',
#        'Sale', 'very', 'Volvo', 'i', '2012', 'Well', 'all', '7', '9',
#        'scratch', 'urgent', 'sell', 'TATA', 'Any', 'Tara'], dtype=object)

# %%
df['name'].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['name_encoded']=encoder.fit_transform(df[['name']])

# %%
df.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.0
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018       0.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.0
#
#    kms_driven fuel_type  name_encoded
# 0     45000.0    Petrol           154
# 1        40.0    Diesel           204
# 2     22000.0    Petrol           254
# 3     28000.0    Petrol           143
# 4     36000.0    Diesel            61

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder=OneHotEncoder()
# encoded=encoder.fit_transform(df[['company']])
# encoded.toarray()
# pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out())

# %%
# from sklearn.preprocessing import LabelEncoder
# encoder=LabelEncoder()
# encoded=encoder.fit_transform(df[['company']])
# df['company_encoded']=encoded

# %%
df.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.0
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018       0.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.0
#
#    kms_driven fuel_type  name_encoded
# 0     45000.0    Petrol           154
# 1        40.0    Diesel           204
# 2     22000.0    Petrol           254
# 3     28000.0    Petrol           143
# 4     36000.0    Diesel            61

# %%
df['fuel_type']=df['fuel_type'].str.strip()

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
encoder=LabelEncoder()
encoded=encoder.fit_transform(df[['fuel_type']])

# %%
df['fuel_type_encoded']=encoded

# %%
df.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000.0
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018       0.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000.0
#
#    kms_driven fuel_type  name_encoded  fuel_type_encoded
# 0     45000.0    Petrol           154                  2
# 1        40.0    Diesel           204                  0
# 2     22000.0    Petrol           254                  2
# 3     28000.0    Petrol           143                  2
# 4     36000.0    Diesel            61                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               892 non-null    object
#  1   company            892 non-null    object
#  2   year               892 non-null    int32
#  3   Price              892 non-null    float64
#  4   kms_driven         892 non-null    float64
#  5   fuel_type          892 non-null    object
#  6   name_encoded       892 non-null    int32
#  7   fuel_type_encoded  892 non-null    int32
# dtypes: float64(2), int32(3), object(3)
# memory usage: 45.4+ KB

# %%
df=df[['name_encoded','year','Price','kms_driven','fuel_type_encoded']]

# %%
df.head()
# Out:
#    name_encoded  year     Price  kms_driven  fuel_type_encoded
# 0           154  2007   80000.0     45000.0                  2
# 1           204  2006  425000.0        40.0                  0
# 2           254  2018       0.0     22000.0                  2
# 3           143  2014  325000.0     28000.0                  2
# 4            61  2014  575000.0     36000.0                  0

# %%
X=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    name_encoded  year     Price  kms_driven
# 0           154  2007   80000.0     45000.0
# 1           204  2006  425000.0        40.0
# 2           254  2018       0.0     22000.0
# 3           143  2014  325000.0     28000.0
# 4            61  2014  575000.0     36000.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((597, 4), (295, 4))

# %%
from sklearn.preprocessing import StandardScaler

# %%
import pickle
def scaler_standard(X_train, X_test):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    file = open('standardScalar.pkl','wb')
    pickle.dump(scaler,file)
    file.close()
    return X_train_scaled, X_test_scaled

# %%
X_train_scaled,X_test_scaled=scaler_standard(X_train,X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression(multi_class='ovr',solver='liblinear',random_state=42)

# %%
clf.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(multi_class='ovr', random_state=42, solver='liblinear')

# %%
y_pred=clf.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7152542372881356

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={
    'penalty':('l1','l2','elasticnet'),
    'C':[1,10,20],
    'solver':['newton-cg','lbfgs','liblinear']
}

# %%
clfcv=GridSearchCV(clf,param_grid=parameter,cv=5)

# %%
clfcv
# Out:
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(multi_class='ovr', random_state=42,
#                                           solver='liblinear'),
#              param_grid={'C': [1, 10, 20],
#                          'penalty': ('l1', 'l2', 'elasticnet'),
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear']})

# %%
clfcv.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(multi_class='ovr', random_state=42,
#                                           solver='liblinear'),
#              param_grid={'C': [1, 10, 20],
#                          'penalty': ('l1', 'l2', 'elasticnet'),
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear']})

# %%
clfcv.best_params_
# Out:
# {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
accuracy_score(y_test,clfcv.predict(X_test_scaled))
# Out:
# 0.7152542372881356

# %%
clf=LogisticRegression(multi_class='ovr',C=1.0,penalty='l1',solver='liblinear')

# %%
clf.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(multi_class='ovr', penalty='l1', solver='liblinear')

# %%
y_pred=clf.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7152542372881356

# %%
import pickle
file=open('modelPrediction.pkl','wb')
pickle.dump(clf,file)
file.close()

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 67,   0,  55],
#        [  2,   0,   0],
#        [ 27,   0, 144]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.55      0.61       122
#            1       0.00      0.00      0.00         2
#            2       0.72      0.84      0.78       171
#
#     accuracy                           0.72       295
#    macro avg       0.47      0.46      0.46       295
# weighted avg       0.71      0.72      0.71       295
